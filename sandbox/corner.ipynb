# %%
import corner
import pandas as pd
import numpy as np

# %%
discarded_patients = pd.read_csv('../emulator/benchmark/discarded_patient.csv')
parameters = ['alpha','beta','gamma','delta']#'DefaultComp.predator', 'DefaultComp.prey']
discarded_patients
# Out:
#      Unnamed: 0      alpha       beta      delta      gamma  \
# 0             0   0.502062  11.840639   2.873084  83.859476
# 1             0   0.502062  11.840639   2.873084  83.859476
# 2             0   5.027910  81.323537  28.709334   1.138515
# 3             0   2.560790   3.046800  46.830225   5.878057
# 4             0   0.282983  29.654354  12.672085   2.188204
# ..          ...        ...        ...        ...        ...
# 493           0   1.643139  21.334424  23.421690  27.918987
# 494           0   1.643139  21.334424  23.421690  27.918987
# 495           0   5.568245  25.596926  66.828092   2.432519
# 496           0   5.568245  25.596926  66.828092   2.432519
# 497           0  79.411490   1.872524  10.565334   0.183933
#
#      DefaultComp.predator  DefaultComp.prey
# 0                     1.0               1.0
# 1                     1.0               1.0
# 2                     1.0               1.0
# 3                     1.0               1.0
# ...

# %%
figure = corner.corner(discarded_patients[parameters])
# Out:
# WARNING:root:Too few points to create valid contours
