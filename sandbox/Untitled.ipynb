# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('benchmark_gauss.csv')

# %%
df
# Out:
#    index             name kernel_type  number_of_samples sampling_type  \
# 0      0    matern_lhs_10      matern                 10           lhs
# 1      1    matern_lhs_21      matern                 21           lhs
# 2      2    matern_lhs_46      matern                 46           lhs
# 3      3   matern_lhs_100      matern                100           lhs
# 4      4   matern_lhs_215      matern                215           lhs
# 5      5   matern_lhs_464      matern                464           lhs
# 6      6  matern_lhs_1000      matern               1000           lhs
# 7      7  matern_lhs_2154      matern               2154           lhs
#
#           MSE          std    median      q_75      q_25      q_90      q_10  \
# 0   85.015802  1618.152010  0.101818  0.688458  0.010895  8.067060  0.001282
# 1   81.630632  1620.941088  0.037584  0.326132  0.003842  1.654282  0.000469
# 2  154.400581  2259.224810  0.054511  0.507574  0.005270  4.234263  0.000304
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot(df_bench.number_of_samples.values[1:],df_bench.score.values[1:], label = 'MSE', marker='*')
plt.title('MSE of the model against the number of point in the traning set')
plt.xlabel('number of point in traning set')

plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
plt.figure(figsize=(10,8))
plt.title('Training time against number of point in the training set')
plt.xlabel('number of point in training set')
plt.ylabel('training time in second')
plt.plot(df.number_of_samples.values,df.time_to_train.values)

# %%
df_bench
# Out:
#     Unnamed: 0        name kernel_type  number_of_samples sampling_type  \
# 2            2   RBF_lhs50         RBF                 50           lhs
# 10           2   RBF_lhs50         RBF                 50           lhs
# 14           6   RBF_lhs73         RBF                 73           lhs
# 18          10   RBF_lhs97         RBF                 97           lhs
# 22          14  RBF_lhs121         RBF                121           lhs
# 26          18  RBF_lhs144         RBF                144           lhs
# 30          22  RBF_lhs168         RBF                168           lhs
# 34          26  RBF_lhs192         RBF                192           lhs
# 38          30  RBF_lhs215         RBF                215           lhs
# 42          34  RBF_lhs239         RBF                239           lhs
# 46          38  RBF_lhs263         RBF                263           lhs
# 50          42  RBF_lhs286         RBF                286           lhs
# ...

# %%
df
# Out:
#     Unnamed: 0             name kernel_type  number_of_samples sampling_type  \
# 0            0    matern_lhs_50      matern                 50           lhs
# 1            1   matern_sobol50      matern                 50         sobol
# 2            2        RBF_lhs50         RBF                 50           lhs
# 3            3      RBF_sobol50         RBF                 50         sobol
# 4            4   matern_lhs_500      matern                500           lhs
# ..         ...              ...         ...                ...           ...
# 83          75     RBF_sobol476         RBF                476         sobol
# 84          76   matern_lhs_500      matern                500           lhs
# 85          77  matern_sobol500      matern                500         sobol
# 86          78       RBF_lhs500         RBF                500           lhs
# 87          79     RBF_sobol500         RBF                500         sobol
#
#            score  time_to_train
# ...
